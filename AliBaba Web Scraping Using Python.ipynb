# %% [markdown]
# ## **Alibaba Web Scraping Using Python**
#
# ### **1. Importing Libraries**

# %%
from bs4 import BeautifulSoup 
import requests 
import time 
import datetime 
import pandas as pd

# %% [markdown]
# *In this section, we import the necessary libraries: BeautifulSoup for parsing HTML, requests for making HTTP requests, time and datetime for handling timestamps, and pandas for organizing and saving the scraped data.*
#
# ---
#
# ### **2. Set Up URL and Headers**

# %%
# URL of the Alibaba product page
URL = 'https://www.alibaba.com/product-detail/MereSports-Men-s-100-Merino-Wool_1601352569953.html?spm=a2700.galleryofferlist.p_offer.d_image.f0d313a0eX1fnF&s=p'

# Custom headers to mimic a real browser request
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36",
    "Accept-Encoding": "gzip, deflate",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8",
    "DNT": "1",
    "Connection": "close",
    "Upgrade-Insecure-Requests": "1"
}

# %% [markdown]
# *In this part, we define the URL of the Alibaba product page and set custom headers to simulate a real browser request. This is necessary to avoid being blocked by the website.*
#
# ---
#
# ### **3. Fetching the Web Page**

# %%
# Send a GET request to fetch the webpage content
page = requests.get(URL, headers=headers)

# Parse the content using BeautifulSoup
soup1 = BeautifulSoup(page.content, "html.parser")
soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

# Print the prettified HTML content (optional for debugging)
print(soup2)
# Out:
# <!-- tangram:5542 begin-->
# <!DOCTYPE html>
#
# <html class="rwd" dir="ltr" lang="en">
# <head>
# <meta content="a2700" name="data-spm"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>
#    Meresports Men's 100% Merino Wool T-shirts Premium Comfort Durability Casual Fit Short Sleeve Fitness Shirts - Buy Merino Wool Shirt
# 100% Merino Wool Tshirt
# merino Wool Sport Cycling
# merino Wool Men
# merino Wool Clothing Manufacturers
# merino Wool Pullover
# 100% Merino Wool Shirt
# merino Wool Underwear
# tshirt Merino Wool
# merino Wool Tshirt
# merino Wool Base Layer
# merino Wool T Shirt
# merino Wool Clothing
# 100% Merino Wool
# 100% Merino Wool Men
# merino Wool Shirt
# merino Wool T-shirts Product on Alibaba.com
#   </title>
# <meta content="Meresports Men's 100% Merino Wool T-shirts Premium Comfort Durability Casual Fit Short Sleeve Fitness Shirts - Buy Merino Wool Shirt
# 100% Merino Wool Tshirt
# merino Wool Sport Cycling
# merino Wool Men
# merino Wool Clothing Manufacturers
# merino Wool Pullover
# 100% Merino Wool Shirt
# merino Wool Underwear
# tshirt Merino Wool
# merino Wool Tshirt
# merino Wool Base Layer
# merino Wool T Shirt
# merino Wool Clothing
# 100% Merino Wool
# 100% Merino Wool Men
# merino Wool Shirt
# merino Wool T-shirts Product on Alibaba.com" name="keywords"/>
# <meta content="Meresports Men's 100% Merino Wool T-shirts Premium Comfort Durability Casual Fit Short Sleeve Fitness Shirts - Buy Merino Wool Shirt
# 100% Merino Wool Tshirt
# merino Wool Sport Cycling
# merino Wool Men
# merino Wool Clothing Manufacturers
# merino Wool Pullover
# 100% Merino Wool Shirt
# merino Wool Underwear
# tshirt Merino Wool
# merino Wool Tshirt
# merino Wool Base Layer
# merino Wool T Shirt
# merino Wool Clothing
# 100% Merino Wool
# 100% Merino Wool Men
# merino Wool Shirt
# merino Wool T-shirts Product on Alibaba.com" name="description">
# <meta content="Meresports Men's 100% Merino Wool T-shirts Premium Comfort Durability Casual Fit Short Sleeve Fitness Shirts - Buy Merino Wool Shirt
# 100% Merino Wool Tshirt
# merino Wool Sport Cycling
# merino Wool Men
# merino Wool Clothing Manufacturers
# merino Wool Pullover
# 100% Merino Wool Shirt
# merino Wool Underwear
# tshirt Merino Wool
# merino Wool Tshirt
# merino Wool Base Layer
# merino Wool T Shirt
# merino Wool Clothing
# 100% Merino Wool
# 100% Merino Wool Men
# merino Wool Shirt
# merino Wool T-shirts Product on Alibaba.com" property="og:title"/>
# <meta content="Meresports Men's 100% Merino Wool T-shirts Premium Comfort Durability Casual Fit Short Sleeve Fitness Shirts - Buy Merino Wool Shirt
# 100% Merino Wool Tshirt
# merino Wool Sport Cycling
# merino Wool Men
# merino Wool Clothing Manufacturers
# merino Wool Pullover
# 100% Merino Wool Shirt
# merino Wool Underwear
# tshirt Merino Wool
# merino Wool Tshirt
# merino Wool Base Layer
# merino Wool T Shirt
# merino Wool Clothing
# 100% Merino Wool
# 100% Merino Wool Men
# merino Wool Shirt
# merino Wool T-shirts Product on Alibaba.com" property="og:description"/>
# <meta content="product" property="og:type"/>
# <meta content="instock" property="og:availability"/>
# <meta content="www.alibaba.com" property="og:site_name"/>
# <meta content="https://www.alibaba.com/product-detail/MereSports-Men-s-100-Merino-Wool_1601352569953.html" property="og:url"/>
# <meta content="https://sc04.alicdn.com/kf/H7a1ce823c3b04b5a9031fd56048c7543w.png" property="og:image"/>
# <link href="//www.alibaba.com/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <meta content="1" name="aplus-icbu-disable-umid"/>
# <link crossorigin="" href="//s.alicdn.com" rel="preconnect"/>
# <link href="//s.alicdn.com" rel="dns-prefetch"/>
# <script>
#      window.__BB_time1=Date.now();
#     </script>
# <link as="image" href="https://s.alicdn.com/@sc04/kf/H7a1ce823c3b04b5a9031fd56048c7543w.png_720x720q50.jpg" rel="preload"/>
# <script>
#       // O2 版本号监测， https://aliyuque.antfin.com/nb/project/kv8r7abczcp8y4em?spm=defwork.home.0.0.5e315c4bSE1P1A#r7rSM
#         window.__aplus_assets_data = {appId: 337938, version: "0.1.107"}
#      </script>
# </meta>
# </head>
# <body class="details-page unite english" data-pdp="true" data-spm="details">
# <script async="" crossorigin="" exparams="userid=&amp;aplus&amp;ali_beacon_id=&amp;ali_apache_id=&amp;ali_apache_track=&amp;ali_apache_tracktmp=&amp;dmtrack_c={}&amp;pageid=4e28b1b52101c1ac1741001572&amp;hn=mobile%2dfreex%2dservice033001193172%2erg%2dus%2deast%2eus44&amp;asid=AQAAAABkk8VnS86+MQAAAAAmDHjhM2xPFA==&amp;sidx=0&amp;tmi=&amp;tmih=&amp;treq=&amp;tres=" id="beacon-aplus" src="//assets.alicdn.com/g/alilog/??aplus_plugin_icbufront/index.js,mlog/aplus_v2.js">
# </script>
# <!-- globalBanner：RecommenderResult(items=[RecommendItem(product=null, supplier=null, buyer=null, news=null, hole=null, tab=null, image=null, pageNo=-1, pageSize=-1, totalNum=-1, nicheBodyList=null, nicheMaterialList=[], extendAttr=null, weight=null, tag=null, sourceType=null, recommendType=null)], totalCount=1, experimentId=null, resultCode=200, messageStack=null, commonResults=null, commonList=null, debugInfo=null, latency=null) 1-->
# <header id="icbu-header">
# <a id="icbu-buyer-pc-top-banner" style="background-image: url(); display: block; position: relative; width: 100%; height: 40px; background-position: 50% center; background-repeat: no-repeat; background-size: 1920px 40px; z-index: 9999;">
# </a>
# <div id="icbu-the-new-header-container">
# <div data-scenes="search-products" data-ssr-version="4.21.4" data-tnh-auto-exp="tnh-expose" data-version="4.4.0" id="the-new-header" style="position: relative;background-color: #fff;border-bottom: 1px solid #ddd;box-sizing: border-box; font-family:Inter,SF Pro Text,Roboto,Helvetica Neue,Helvetica,Tahoma,Arial,PingFang SC,Microsoft YaHei;">
# <div style="display: flex;align-items: center;height: 72px;min-width: 1200px;max-width: 1580px;margin: 0 auto;padding: 0px 40px;box-sizing: border-box;">
# <img alt="" src="https://s.alicdn.com/@img/imgextra/i1/O1CN01e5zQ2S1cAWz26ivMo_!!6000000003560-2-tps-920-110.png" style="height: 22px; width: auto;"/>
# </div>
# <div style="min-width: 1200px;max-width: 1580px;height: 36px;margin: 0 auto;overflow: hidden;font-size: 14px;display: flex;justify-content: space-between;padding: 0 40px;box-sizing: border-box;">
# <div style="display: flex; align-items: center; justify-content: space-between">
# <div style="position: relative; height: 36px; padding: 0 28px 0 20px">
#         All categories
#        </div>
# <div style="position: relative; height: 36px; padding-right: 28px">
#         Featured selections
#        </div>
# <div style="position: relative; height: 36px">
#         Trade Assurance
#        </div>
# </div>
# <div style="display: flex; align-items: center; justify-content: space-between">
# <div style="position: relative; height: 36px; padding-right: 28px">
#         Buyer Central
#        </div>
# <div style="position: relative; height: 36px; padding-right: 28px">
#         Help Center
#        </div>
# <div style="position: relative; height: 36px; padding-right: 28px">
#         Get the app
#        </div>
# <div style="position: relative; height: 36px">
#         Become a supplier
#        </div>
# </div>
# </div>
# </div>
# </div>
# </header>
# <!-- CSS 内容，内联开关关闭后走常规 link 逻辑-->
# <link href="//s.alicdn.com/@g/sc/detail-fantasy/0.1.107/index.css" rel="stylesheet"/>
# <link as="style" href="//s.alicdn.com/@g/sc/detail-fantasy/0.1.107/globalHeader.css" onload="this.rel='stylesheet'" rel="preload"/>
# <noscript>
# <link href="//s.alicdn.com/@g/sc/detail-fantasy/0.1.107/globalHeader.css" rel="stylesheet"/>
# </noscript>
# <script>
#    window.staticHeaderHtml = true;
#         window.__BB_time2=Date.now();
#   </script>
# <!-- htmlbefore -->
# <!-- 性能试验参数 {detail_review_floor=VO, reviewNewTest=VO, ShopReviewTest=VO, certificateTest=certificate_high, ds_in_detail_pc=VO, product_reviews=VO, deliveryGuaranteeTest=VA, FixPriceAppTest=VO, pc_old_detail_main_action=VO, productReviewTest=VO, ds_in_detail_app=VO, pc_detail_multi_lang_text=VO, PoOfflineTest=noButton, pc_detail_company_card_20241212=VO, GlobalTopProductTest=VO, pc_action_optimisation_2=VO, chatStrongTest=VO, csTestVersion=VA, RTSByCountryTest=VO, goldCompanyCardTest=VA, MinisiteEntranceTest=VO, pc_detail_send_order_request=VO, wap_detail_ui_upgrade=VO, RecommendListTest=entrance_with_url_recommend_after_sample, FixPricePcTest=VO, MainPictureTest=VO} -->
# <script>
#    // 流式渲染第二段开始打点
#         window.__BB_time3=Date.now();
#
#
#
#         window.__BB = {
#             scene: 'details'
#         };
#
#                 if (decodeURIComponent(document.cookie).indexOf('tenant') > 0){
#             window.__BB.scene = 'detail-country';
#         }
#                 window.__APLUS_ABRATE__ = window.__APLUS_ABRATE__ || {};
#         window.__APLUS_ABRATE__ = Object.assign(window.__APLUS_ABRATE__, {
#             'pdp': "true",
#             'perf_group': '',
#             scene: window.__BB['scene'],
#         });
#   </script>
# <div class="root-layout" id="container">
# <!-- Silkworm Render: 2101c5c217410015721167815e1070 -->
# <div class="layout-body">
# <div class="layout-left">
# <div class="" data-section="SectionOverview">
# <div class="module_title" data-module-name="module_title">
# <div class="product-title-container">
# <h1 title="MereSports Men's 100% Merino Wool T-Shirts Premium Comfort Durability Casual Fit Short Sleeve Fitness Shirts">
# <img src="https://s.alicdn.com/@img/imgextra/i3/O1CN01vyjd0W1FSB7PNiQyK_!!6000000000485-2-tps-80-32.png"/>
#          MereSports Men's 100% Merino Wool T-Shirts Premium Comfort Durability Casual Fit Short Sleeve Fitness Shirts
#         </h1>
# </div>
# </div>
# <div class="module_comment" data-module-name="module_comment">
# <div class="detail-product-comment">
# <span class="detail-review-item detail-star detail-separator">
# <span class="detail-review-item detail-separator">
#           No reviews yet
#          </span>
# </span>
# </div>
# </div>
# <div class="module_company" data-module-name="module_company">
# <div class="product-company" style="background-image:url(https://s.alicdn.com/@img/imgextra/i4/O1CN01vkS5p71sQabHhuw1U_!!6000000005761-2-tps-2250-144.png)">
# <img alt="company-logo" class="company-logo" loading="lazy" src="https://sc04.alicdn.com/kf/H51870e8578234d48aea040d337dccaa0k.png_80x80.png"/>
# <div class="product-company-info">
# <span class="company-name detail-separator">
# <a href="https://meresports.en.alibaba.com/index.html?from=detail&amp;productId=1601352569953" target="_blank" title="Shanghai Meresports Apparel Co., Ltd.">
#            Shanghai Meresports Apparel Co., Ltd.
#           </a>
# </span>
# <a class="verify-icon" href="//sale.alibaba.com/p/d7v3mp6m3" rel="nofollow" target="_blank">
# <img loading="lazy" src="https://s.alicdn.com/@img/imgextra/i2/O1CN01OhiUgP22fNY7nmUGL_!!6000000007147-2-tps-153-39.png"/>
# </a>
# <span class="company-identity detail-separator">
#           Multispecialty supplier
#          </span>
# <span class="company-life detail-separator">
#           3 yrs
#          </span>
# <span class="company-country detail-separator">
# <img loading="lazy" src="https://s.alicdn.com/@u/mobile/g/common/flags/1.0.0/assets/cn.png"/>
# <span class="register-country">
#            CN
#           </span>
# </span>
# </div>
# </div>
# </div>
# <div class="module_productImage" data-module-name="module_productImage">
# <div class="main-index" data-module="MainImage">
# <div class="id-flex id-justify-around id-aspect-[16/10]">
# <div class="id-mr-5 id-w-16 sm:id-mr-2 md:id-mr-10" data-submodule="ProductImageThumbsList">
# <div aria-roledescription="carousel" class="id-relative id-h-full id-w-[64px]" data-testid="product-image-list" role="region">
# <div class="id-overflow-hidden id-h-full">
# <div class="id-flex id--mt-4 id-flex-col id--mt-5 id-h-full">
# <div aria-roledescription="slide" class="id-min-w-0 id-shrink-0 id-grow-0 id-relative id-basis-1/6 id-pt-5" role="group">
# <div class="id-relative id-flex id-aspect-square id-w-16 id-cursor-pointer id-items-center id-justify-center id-overflow-hidden id-rounded-lg id-bg-contain id-bg-center id-bg-no-repeat id-border-2 id-border-black" style="background-image:url(//s.alicdn.com/@sc04/kf/H7a1ce823c3b04b5a9031fd56048c7543w.png_80x80.jpg)">
# <div class="id-absolute id-bottom-0 id-left-0 id-right-0 id-top-0 id-bg-black id-opacity-5">
# </div>
# </div>
# </div>
# <div aria-roledescription="slide" class="id-min-w-0 id-shrink-0 id-grow-0 id-relative id-basis-1/6 id-pt-5" role="group">
# <div class="id-relative id-flex id-aspect-square id-w-16 id-cursor-pointer id-items-center id-justify-center id-overflow-hidden id-rounded-lg id-bg-contain id-bg-center id-bg-no-repeat" style="background-image:url(//s.alicdn.com/@sc04/kf/Hd7d78cc092b4418f8abcfc633e9dbbd5u.png_80x80.jpg)">
# <div class="id-absolute id-bottom-0 id-left-0 id-right-0 id-top-0 id-bg-black id-opacity-5">
# </div>
# </div>
# </div>
# <div aria-roledescription="slide" class="id-min-w-0 id-shrink-0 id-grow-0 id-relative id-basis-1/6 id-pt-5" role="group">
# <div class="id-relative id-flex id-aspect-square id-w-16 id-cursor-pointer id-items-center id-justify-center id-overflow-hidden id-rounded-lg id-bg-contain id-bg-center id-bg-no-repeat" style="background-image:url(//s.alicdn.com/@sc04/kf/H4d022a933c1d4429b17d25d97f691ce2q.png_80x80.jpg)">
# <div class="id-absolute id-bottom-0 id-left-0 id-right-0 id-top-0 id-bg-black id-opacity-5">
# </div>
# </div>
# </div>
# <div aria-roledescription="slide" class="id-min-w-0 id-shrink-0 id-grow-0 id-relative id-basis-1/6 id-pt-5" role="group">
# <div class="id-relative id-flex id-aspect-square id-w-16 id-cursor-pointer id-items-center id-justify-center id-overflow-hidden id-rounded-lg id-bg-contain id-bg-center id-bg-no-repeat" style="background-image:url(//s.alicdn.com/@sc04/kf/H916128c9d7cd49a98ae3cdf5d551be2cP.png_80x80.jpg)">
# <div class="id-absolute id-bottom-0 id-left-0 id-right-0 id-top-0 id-bg-black id-opacity-5">
# </div>
# </div>
# </div>
# <div aria-roledescription="slide" class="id-min-w-0 id-shrink-0 id-grow-0 id-relative id-basis-1/6 id-pt-5" role="group">
# <div class="id-relative id-flex id-aspect-square id-w-16 id-cursor-pointer id-items-center id-justify-center id-overflow-hidden id-rounded-lg id-bg-contain id-bg-center id-bg-no-repeat" style="background-image:url(//s.alicdn.com/@sc04/kf/H9833b4a6d4c24630b6bbe886f4973886j.png_80x80.jpg)">
# <div class="id-absolute id-bottom-0 id-left-0 id-right-0 id-top-0 id-bg-black id-opacity-5">
# </div>
# </div>
# </div>
# <div aria-roledescription="slide" class="id-min-w-0 id-shrink-0 id-grow-0 id-relative id-basis-1/6 id-pt-5" role="group">
# <div class="id-relative id-flex id-aspect-square id-w-16 id-cursor-pointer id-items-center id-justify-center id-overflow-hidden id-rounded-lg id-bg-contain id-bg-center id-bg-no-repeat" style="background-image:url(//s.alicdn.com/@sc04/kf/H6610477d780e4a90beddae86fff6c9889.png_80x80.jpg)">
# <div class="id-absolute id-bottom-0 id-left-0 id-right-0 id-top-0 id-bg-black id-opacity-5">
# </div>
# </div>
# </div>
# </div>
# </div>
# <button class="id-inline-flex id-items-center id-justify-center id-whitespace-nowrap id-text-sm id-font-medium id-ring-offset-background id-transition-colors focus-visible:id-outline-none focus-visible:id-ring-2 focus-visible:id-ring-ring focus-visible:id-ring-offset-2 disabled:id-pointer-events-none disabled:id-opacity-40 id-border id-border-input id-bg-background hover:id-bg-accent hover:id-text-accent-foreground id-absolute id-h-8 id-w-8 id-rounded-full id-left-1/2 id-top-2 id--translate-x-1/2 id-rotate-90" disabled="">
# <svg class="lucide lucide-chevron-left id-h-6 id-w-6" fill="none" height="24" stroke="currentColor" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="m15 18-6-6 6-6">
# </path>
# </svg>
# <span class="id-sr-only">
#              Previous slide
#             </span>
# </button>
# <button class="id-inline-flex id-items-center id-justify-center id-whitespace-nowrap id-text-sm id-font-medium id-ring-offset-background id-transition-colors focus-visible:id-outline-none focus-visible:id-ring-2 focus-visible:id-ring-ring focus-visible:id-ring-offset-2 disabled:id-pointer-events-none disabled:id-opacity-40 id-border id-border-input id-bg-background hover:id-bg-accent hover:id-text-accent-foreground id-absolute id-h-8 id-w-8 id-rounded-full id-bottom-2 id-left-1/2 id--translate-x-1/2 id-rotate-90" disabled="">
# <svg class="lucide lucide-chevron-right id-h-6 id-w-6" fill="none" height="24" stroke="currentColor" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="m9 18 6-6-6-6">
# </path>
# </svg>
# <span class="id-sr-only">
#              Next slide
#             </span>
# </button>
# </div>
# </div>
# <div class="id-relative id-flex-1" data-submodule="ProductImageMain">
# <div aria-roledescription="carousel" class="id-relative id-h-full id-w-full" data-testid="product-image-view" role="region">
# <div class="id-overflow-hidden id-h-full">
# <div class="id-flex id--ml-4 id-h-full">
# <div aria-roledescription="slide" class="id-min-w-0 id-shrink-0 id-grow-0 id-basis-full id-pl-4 id-h-full id-cursor-pointer" role="group">
# <div class="id-h-full id-w-full id-overflow-hidden id-rounded-xl">
# <div class="id-relative id-h-full id-w-full" data-testid="media-image">
# <div class="id-absolute id-bottom-0 id-left-0 id-right-0 id-top-0 -id-z-10 id-bg-black id-opacity-5">
# </div>
# <img alt="MereSports Men's 100% Merino Wool T-Shirts Premium Comfort Durability Casual Fit Short Sleeve Fitness Shirts" class="id-h-full id-w-full id-object-contain" loading="eager" src="//s.alicdn.com/@sc04/kf/H7a1ce823c3b04b5a9031fd56048c7543w.png_720x720q50.jpg"/>
# </div>
# </div>
# </div>
# <div aria-roledescription="slide" class="id-min-w-0 id-shrink-0 id-grow-0 id-basis-full id-pl-4 id-h-full id-cursor-pointer" role="group">
# <div class="id-h-full id-w-full id-overflow-hidden id-rounded-xl">
# <div class="id-relative id-h-full id-w-full" data-testid="media-image">
# <div class="id-absolute id-bottom-0 id-left-0 id-right-0 id-top-0 -id-z-10 id-bg-black id-opacity-5">
# </div>
# <img alt="MereSports Men's 100% Merino Wool T-Shirts Premium Comfort Durability Casual Fit Short Sleeve Fitness Shirts" class="id-h-full id-w-full id-object-contain" loading="lazy" src="//s.alicdn.com/@sc04/kf/Hd7d78cc092b4418f8abcfc633e9dbbd5u.png_720x720q50.jpg"/>
# </div>
# </div>
# </div>
# <div aria-roledescription="slide" class="id-min-w-0 id-shrink-0 id-grow-0 id-basis-full id-pl-4 id-h-full id-cursor-pointer" role="group">
# <div class="id-h-full id-w-full id-overflow-hidden id-rounded-xl">
# <div class="id-relative id-h-full id-w-full" data-testid="media-image">
# <div class="id-absolute id-bottom-0 id-left-0 id-right-0 id-top-0 -id-z-10 id-bg-black id-opacity-5">
# </div>
# <img alt="MereSports Men's 100% Merino Wool T-Shirts Premium Comfort Durability Casual Fit Short Sleeve Fitness Shirts" class="id-h-full id-w-full id-object-contain" loading="lazy" src="//s.alicdn.com/@sc04/kf/H4d022a933c1d4429b17d25d97f691ce2q.png_720x720q50.jpg"/>
# </div>
# </div>
# </div>
# <div aria-roledescription="slide" class="id-min-w-0 id-shrink-0 id-grow-0 id-basis-full id-pl-4 id-h-full id-cursor-pointer" role="group">
# <div class="id-h-full id-w-full id-overflow-hidden id-rounded-xl">
# <div class="id-relative id-h-full id-w-full" data-testid="media-image">
# <div class="id-absolute id-bottom-0 id-left-0 id-right-0 id-top-0 -id-z-10 id-bg-black id-opacity-5">
# </div>
# <img alt="MereSports Men's 100% Merino Wool T-Shirts Premium Comfort Durability Casual Fit Short Sleeve Fitness Shirts" class="id-h-full id-w-full id-object-contain" loading="lazy" src="//s.alicdn.com/@sc04/kf/H916128c9d7cd49a98ae3cdf5d551be2cP.png_720x720q50.jpg"/>
# </div>
# </div>
# </div>
# <div aria-roledescription="slide" class="id-min-w-0 id-shrink-0 id-grow-0 id-basis-full id-pl-4 id-h-full id-cursor-pointer" role="group">
# <div class="id-h-full id-w-full id-overflow-hidden id-rounded-xl">
# <div class="id-relative id-h-full id-w-full" data-testid="media-image">
# <div class="id-absolute id-bottom-0 id-left-0 id-right-0 id-top-0 -id-z-10 id-bg-black id-opacity-5">
# </div>
# <img alt="MereSports Men's 100% Merino Wool T-Shirts Premium Comfort Durability Casual Fit Short Sleeve Fitness Shirts" class="id-h-full id-w-full id-object-contain" loading="lazy" src="//s.alicdn.com/@sc04/kf/H9833b4a6d4c24630b6bbe886f4973886j.png_720x720q50.jpg"/>
# </div>
# </div>
# </div>
# <div aria-roledescription="slide" class="id-min-w-0 id-shrink-0 id-grow-0 id-basis-full id-pl-4 id-h-full id-cursor-pointer" role="group">
# <div class="id-h-full id-w-full id-overflow-hidden id-rounded-xl">
# <div class="id-relative id-h-full id-w-full" data-testid="media-image">
# <div class="id-absolute id-bottom-0 id-left-0 id-right-0 id-top-0 -id-z-10 id-bg-black id-opacity-5">
# </div>
# <img alt="MereSports Men's 100% Merino Wool T-Shirts Premium Comfort Durability Casual Fit Short Sleeve Fitness Shirts" class="id-h-full id-w-full id-object-contain" loading="lazy" src="//s.alicdn.com/@sc04/kf/H6610477d780e4a90beddae86fff6c9889.png_720x720q50.jpg"/>
# </div>
# </div>
# </div>
# </div>
# </div>
# <button class="id-inline-flex id-items-center id-justify-center id-whitespace-nowrap id-text-sm id-font-medium id-ring-offset-background id-transition-colors focus-visible:id-outline-none focus-visible:id-ring-2 focus-visible:id-ring-ring focus-visible:id-ring-offset-2 disabled:id-pointer-events-none disabled:id-opacity-40 id-border id-border-input id-bg-background hover:id-bg-accent hover:id-text-accent-foreground id-absolute id-rounded-full id-top-1/2 id--translate-y-1/2 id-left-4 id-h-12 id-w-12" data-testid="main-image-prev" disabled="">
# <svg class="lucide lucide-chevron-left id-h-6 id-w-6" fill="none" height="24" stroke="currentColor" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="m15 18-6-6 6-6">
# </path>
# </svg>
# <span class="id-sr-only">
#              Previous slide
#             </span>
# </button>
# <button class="id-inline-flex id-items-center id-justify-center id-whitespace-nowrap id-text-sm id-font-medium id-ring-offset-background id-transition-colors focus-visible:id-outline-none focus-visible:id-ring-2 focus-visible:id-ring-ring focus-visible:id-ring-offset-2 disabled:id-pointer-events-none disabled:id-opacity-40 id-border id-border-input id-bg-background hover:id-bg-accent hover:id-text-accent-foreground id-absolute id-rounded-full id-top-1/2 id--translate-y-1/2 id-right-4 id-h-12 id-w-12" data-testid="main-image-next" disabled="">
# <svg class="lucide lucide-chevron-right id-h-6 id-w-6" fill="none" height="24" stroke="currentColor" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="m9 18 6-6-6-6">
# </path>
# </svg>
# <span class="id-sr-only">
#              Next slide
#             </span>
# </button>
# </div>
# <div class="id-absolute id-right-4 id-top-4 id-cursor-pointer id-rounded-full id-bg-white id-p-2 id-opacity-80 hover:id-shadow">
# <svg class="detail-icon-favorite" height="30" width="30">
# <use xlink:href="#icon-follow">
# </use>
# </svg>
# </div>
# <div class="detail-find-similar-container">
# <div class="searchx-find-similar__wrapper detail-find-similar">
# <div class="searchx-find-similar searchx-find-similar__icon theme-translucent" data-aplus-similar-dot="productId=1601352569953&amp;imgUrl=https://s.alicdn.com/@sc04/kf/H7a1ce823c3b04b5a9031fd56048c7543w.png_300x300.jpg&amp;scene=detailMainImg&amp;companyId=undefined&amp;currentImgIndex=0">
# <img class="searchx-find-similar__img" loading="lazy" src="//s.alicdn.com/@img/imgextra/i1/O1CN01H0fqnK1Gpp8Bpra4W_!!6000000000672-55-tps-20-21.svg"/>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="" data-section="SectionDetails">
# <div class="module_recommend" data-module-name="module_recommend">
# <div class="recommend-layout you_may_like" data-module-name="module_you_may_like">
# <div id="cdn-pc-recommend_detail__you_may_like">
# </div>
# </div>
# </div>
# <div class="module_sellingpoint" data-module-name="module_sellingpoint">
# </div>
# <div class="module_industry_compatible_vehicles_up" data-module-name="module_industry_compatible_vehicles_up">
# </div>
# <div class="module_attribute" data-module-name="module_attribute">
# <div class="attribute-layout show-more">
# <h2 class="att-title" id="key-attributes">
#          Key attributes
#         </h2>
# <div class="attribute-info">
# <h3>
#           Industry-specific attributes
#          </h3>
# <div class="attribute-list">
# <div class="attribute-item">
# <div class="left">
#             Material
#            </div>
# <div class="right">
# <span>
#              Merino wool
#             </span>
# </div>
# </div>
# <div class="attribute-item">
# <div class="left">
#             Fabric Weight
#            </div>
# <div class="right">
# <span>
#              180 Grams
#             </span>
# </div>
# </div>
# </div>
# <h3>
#           Other attributes
#          </h3>
# <div class="attribute-list">
# <div class="attribute-item">
# <div class="left">
#             Collar
#            </div>
# <div class="right">
# <span>
#              O-Neck
#             </span>
# </div>
# </div>
# <div class="attribute-item">
# <div class="left">
#             Printing Methods
#            </div>
# <div class="right">
# <span>
#              Heat-transfer Printing
#             </span>
# </div>
# </div>
# <div class="attribute-item">
# <div class="left">
#             Technics
#            </div>
# <div class="right">
# <span>
#              YARN DYED
#             </span>
# </div>
# </div>
# <div class="attribute-item">
# <div class="left">
#             Sleeve Style
#            </div>
# <div class="right">
# <span>
#              Regular
#             </span>
# </div>
# </div>
# <div class="attribute-item">
# <div class="left">
#             Fit Type
#            </div>
# <div class="right">
# <span>
#              slim fit
#             </span>
# </div>
# </div>
# <div class="attribute-item">
# <div class="left">
#             Weaving method
#            </div>
# <div class="right">
# <span>
#              knitted
#             </span>
# </div>
# </div>
# <div class="attribute-item">
# <div class="left">
#             Fabric Type
#            </div>
# <div class="right">
# <span>
#              Jersey
#             </span>
# </div>
# </div>
# <div class="attribute-item">
# <div class="left">
#             Design
#            </div>
# <div class="right">
# <span>
#              Blank
#             </span>
# </div>
# </div>
# <div class="attribute-item">
# <div class="left">
#             Length
#            </div>
# <div class="right">
# <span>
#              Regular
#             </span>
# </div>
# </div>
# <div class="attribute-item">
# <div class="left">
#             Pattern Type
#            </div>
# <div class="right">
# <span>
#              Solid
#             </span>
# </div>
# </div>
# <div class="attribute-item">
# <div class="left">
#             Style
#            </div>
# <div class="right">
# <span>
#              Casual
#             </span>
# </div>
# </div>
# <div class="attribute-item">
# <div class="left">
#             Feature
#            </div>
# <div class="right">
# <span>
#              Anti-pilling, Breathable, Anti-UV, Sustainable, Anti-Shrink
#             </span>
# </div>
# </div>
# <div class="attribute-item">
# <div class="left">
#             7 days sample order lead time
#            </div>
# <div class="right">
# <span>
#              Support
#             </span>
# </div>
# </div>
# <div class="attribute-item">
# <div class="left">
#             Needle detection
#            </div>
# <div class="right">
# <span>
#              Yes
#             </span>
# </div>
# </div>
# <div class="attribute-item">
# <div class="left">
#             Place of Origin
#            </div>
# <div class="right">
# <span>
#              Shanghai, China
#             </span>
# </div>
# </div>
# <div class="attribute-item">
# <div class="left">
#             logo/pattern
#            </div>
# <div class="right">
# <span>
#              Digital printing
#             </span>
# </div>
# </div>
# <div class="attribute-item">
# <div class="left">
#             Gender
#            </div>
# <div class="right">
# <span>
#              Men
#             </span>
# </div>
# </div>
# <div class="attribute-item">
# <div class="left">
#             Brand Name
#            </div>
# <div class="right">
# <span>
#              MereSports
#             </span>
# </div>
# </div>
# </div>
# <h3>
#           Packaging and delivery
#          </h3>
# <div class="attribute-list">
# <div class="attribute-item">
# <div class="left">
#             Selling Units:
#            </div>
# <div class="right">
# <span>
#              Single item
#             </span>
# </div>
# </div>
# <div class="attribute-item">
# <div class="left">
#             Single package size:
#            </div>
# <div class="right">
# <span>
#              30X40X3 cm
#             </span>
# </div>
# </div>
# <div class="attribute-item">
# <div class="left">
#             Single gross weight:
#            </div>
# <div class="right">
# <span>
#              0.300 kg
#             </span>
# </div>
# </div>
# </div>
# <div class="more-bg">
# <a href="#">
#            Show more
#           </a>
# <svg class="detail-symbol">
# <use xlink:href="#icon-down">
# </use>
# </svg>
# </div>
# </div>
# </div>
# </div>
# <div class="module_lead" data-module-name="module_lead">
# <div class="lead-layout">
# <h2 class="collapsible-title">
#          Lead time
#          <svg class="detail-symbol">
# <use xlink:href="#icon-down">
# </use>
# </svg>
# </h2>
# <div class="collapsible-layout hidden">
# <div class="lead-list">
# <table>
# <tbody>
# <tr>
# <td>
#               Quantity (pieces)
#              </td>
# <td>
#               1 - 500
#              </td>
# <td>
#               501 - 2000
#              </td>
# <td>
#               &gt; 2000
#              </td>
# </tr>
# <tr>
# <td>
#               Lead time (days)
#              </td>
# <td>
#               70
#              </td>
# <td>
#               80
#              </td>
# <td>
#               To be negotiated
#              </td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </div>
# <div class="module_sample" data-module-name="module_sample">
# <div class="sample-layout">
# <div class="sample-action">
#          Still deciding? Get samples first!
#          <a href="#">
#           Order sample
#          </a>
# </div>
# <div class="sample-floor">
# <h2 class="att-title" id="samples">
#           Samples
#          </h2>
# <div class="sample-item">
#           Maximum order quantity:  1 piece
#          </div>
# <div class="sample-item">
# <span>
#            Sample price:
#           </span>
# <div class="price">
# <strong>
#             $50.00/piece
#            </strong>
# </div>
# </div>
# <button class="detail-simple">
#           Order sample
#          </button>
# </div>
# </div>
# </div>
# <div class="module_detail_selection_tool" data-module-name="module_detail_selection_tool">
# <div class="selection-tool-wrapper" data-auto-exp="module-selectionTool" data-module-name="performance-analysis">
# </div>
# </div>
# <div class="module_customization" data-module-name="module_customization">
# </div>
# <div class="module_certification" data-module-name="module_certification">
# </div>
# <div class="module_project" data-module-name="module_project">
# </div>
# <div class="module_service" data-module-name="module_service">
# </div>
# <div class="module_review" data-module-name="module_review">
# </div>
# <div class="module_card" data-module-name="module_card">
# </div>
# <div class="module_unifed_company_card" data-module-name="module_unifed_company_card">
# </div>
# <div class="module_description" data-module-name="module_description">
# <div class="description-layout" id="description-layout">
# <h2 class="att-title" id="more-detail">
#          Product descriptions from the supplier
#         </h2>
# <div id="layout-other-wrapper">
# <div class="module_shopping_ads" data-module-name="module_shopping_ads">
# </div>
# <div class="module_shop_marking" data-module-name="module_shop_marking">
# </div>
# <div class="module_risk_control_tips" data-module-name="module_risk_control_tips">
# </div>
# <div class="module_detail_video" data-module-name="module_detail_video">
# </div>
# <div class="module_product_specification" data-module-name="module_product_specification">
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="layout-right" data-layout="layout-right">
# <div class="layout-stick" data-layout="layout-stick">
# <div class="layout-overview" data-layout="layout-overview">
# <div class="" data-section="SectionAction">
# <div class="module_atmosphere" data-module-name="module_atmosphere">
# </div>
# <div class="module_product_highlights" data-module-name="module_product_highlights">
# </div>
# <div class="module_free_shipping" data-module-name="module_free_shipping">
# </div>
# <div class="module_price" data-module-name="module_price">
# <div class="product-price">
# <div class="price-list">
# <div class="price-item">
# <div class="quality">
#              500 - 1999 pieces
#             </div>
# <div class="price">
# <span class="">
#               $16.50
#              </span>
# </div>
# </div>
# <div class="price-item">
# <div class="quality">
#              &gt;= 2000 pieces
#             </div>
# <div class="price">
# <span class="">
#               $15.50
#              </span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="module_sku" data-module-name="module_sku">
# <div class="id-px-5" data-show-type="skuSummary" data-testid="sku-layout">
# <div data-testid="sku-options">
# <h3 class="id-mb-4 id-text-lg id-font-semibold">
#             Variations
#            </h3>
# <div class="id-mt-2 id-flex id-w-full id-flex-row id-justify-between id-gap-5">
# <div class="id-truncate id-text-sm" data-testid="default-stats">
# <span class="">
#               Total options:
#              </span>
# <span class="id-ml-2 id-font-bold">
# </span>
# </div>
# <a class="id-whitespace-nowrap id-text-base id-font-semibold id-text-primary id-underline" data-testid="sku-action" href="#">
#              Select now
#             </a>
# </div>
# </div>
# <div data-testid="sku-info">
# </div>
# <div class="sku-logistic" data-testid="sku-logistic">
# <div class="id-flex id-items-center id-justify-between">
# <h3 class="id-m-0 id-text-lg id-font-semibold">
#              Shipping
#             </h3>
# </div>
# <div class="logistic-item id-mt-3 id-text-sm">
# <span class="id-text-sm">
#              Shipping fee and delivery date to be negotiated. Chat with supplier now for more details.
#             </span>
# </div>
# </div>
# </div>
# </div>
# <div class="right-bottom id-bg-white">
# <div class="module_actions" data-module-name="module_actions">
# <div class="id-flex id-items-center id-justify-center id-gap-3 id-px-5 buttons-layout-double">
# <div class="im-alitalk-container Highlight" style="cursor:pointer">
# <button class="id-inline-flex id-items-center id-justify-center id-whitespace-nowrap id-text-sm id-ring-offset-background id-transition-colors focus-visible:id-outline-none focus-visible:id-ring-2 focus-visible:id-ring-ring focus-visible:id-ring-offset-2 disabled:id-pointer-events-none disabled:id-opacity-40 id-bg-primary id-text-primary-foreground hover:id-opacity-90 id-py-2 id-h-12 id-w-full id-gap-1 id-text-wrap id-rounded-full id-border-[#222] id-px-0 id-font-bold" data-testid="skuSummary-INQUIRY" style="background-color:#FF6A00;color:#FFFFFF">
# <span class="id-line-clamp-2">
#               Send inquiry
#              </span>
# </button>
# </div>
# <div class="im-alitalk-container Normal" style="cursor:pointer">
# <button class="id-inline-flex id-items-center id-justify-center id-whitespace-nowrap id-text-sm id-ring-offset-background id-transition-colors focus-visible:id-outline-none focus-visible:id-ring-2 focus-visible:id-ring-ring focus-visible:id-ring-offset-2 disabled:id-pointer-events-none disabled:id-opacity-40 id-border id-bg-background hover:id-bg-accent hover:id-text-accent-foreground id-py-2 id-h-12 id-w-full id-gap-1 id-text-wrap id-rounded-full id-border-[#222] id-px-0 id-font-bold" data-testid="skuSummary-CHAT" style="background-color:#FFFFFF;color:#222222">
# <span class="id-line-clamp-2">
#               Chat now
#              </span>
# </button>
# </div>
# </div>
# </div>
# <div class="module_actions" data-module-name="module_actions">
# <div class="id-flex id-items-center id-justify-center id-gap-3 id-px-5 buttons-layout-single">
# <span class="id-text-base">
#             Still deciding? Get samples first!
#             <button class="id-inline-flex id-items-center id-justify-center id-whitespace-nowrap id-rounded-md id-ring-offset-background id-transition-colors focus-visible:id-outline-none focus-visible:id-ring-2 focus-visible:id-ring-ring focus-visible:id-ring-offset-2 disabled:id-pointer-events-none disabled:id-opacity-40 id-underline-offset-4 hover:id-underline id-h-10 id-px-1 id-py-0 id-text-base id-font-normal id-text-[#222] id-underline" data-testid="skuSummary-SAMPLE" style="color:#222222">
#              Order sample
#             </button>
# </span>
# </div>
# </div>
# </div>
# <div class="module_dropshipping" data-module-name="module_dropshipping">
# </div>
# <div class="module_bnplPayment" data-module-name="module_bnplPayment">
# </div>
# <div class="module_shipping" data-module-name="module_shipping">
# </div>
# <div class="module_coupon" data-module-name="module_coupon">
# </div>
# <div class="module_benefits" data-module-name="module_benefits">
# </div>
# <div class="module_ta_plus" data-module-name="module_ta_plus">
# <div class="ta-semi">
# <div class="ta-wrapper">
# <div class="ta-header">
# <div class="ta-item">
# <h3 class="title">
#               Protections for this product
#              </h3>
# </div>
# </div>
# <svg class="detail-symbol">
# <use xlink:href="#icon-right">
# </use>
# </svg>
# </div>
# <div class="semi-list">
# <div class="semi-item">
# <div style="color:#undefined">
# <img src="https://sc01.alicdn.com/kf/H36976abd62fb46ef8ed67f86ae2ccff1s.png"/>
# <div>
# <h4>
#                Secure payments
#               </h4>
# <img/>
# </div>
# </div>
# <p>
#              Every payment you make on Alibaba.com is secured with strict SSL encryption and PCI DSS data protection protocols
#             </p>
# </div>
# <div class="semi-item">
# <div style="color:#undefined">
# <img src="https://gw.alicdn.com/imgextra/i1/O1CN01gDq0hh1yfbKcuFDYe_!!6000000006606-2-tps-60-60.png"/>
# <div>
# <h4>
#                Easy Return &amp; Refund
#               </h4>
# <img/>
# </div>
# </div>
# <p>
#              Claim a refund if your order is missing or arrives with product issues, plus free local returns for defects on qualifying purchases
#             </p>
# </div>
# </div>
# <div class="semi-footer">
#            Alibaba.com protects all your orders placed and paid on the platform with
#            <img src="https://sc01.alicdn.com/kf/Hfddaf74a86174ede9cc528d9da95f789D.png"/>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="" data-section="SectionActionPanel">
# <div class="module_skuPanel" data-module-name="module_skuPanel">
# </div>
# </div>
# <div class="id-mx-auto id-px-10 sm:id-w-screenSm md:id-w-screenMd lg:id-w-screenLg" data-section="SectionAdditional">
# <div class="module_together" data-module-name="module_together">
# <div class="recommend-layout buy_together" data-module-name="module_buy_together">
# <div id="cdn-pc-recommend_detail__buy_together">
# </div>
# </div>
# </div>
# <div class="module_popular" data-module-name="module_popular">
# <div class="recommend-layout popular_products" data-module-name="module_popular_products">
# <div id="cdn-pc-recommend_detail__popular_products">
# </div>
# </div>
# </div>
# <div class="module_seo" data-module-name="module_seo">
# <div class="related-layout">
# <h2>
#        Related searches
#       </h2>
# <div class="related-list">
# <a href="https://www.alibaba.com/showroom/shirts.html" target="_blank">
#         shirts
#        </a>
# <a href="https://www.alibaba.com/showroom/denim-shirt.html" target="_blank">
#         denim shirt
#        </a>
# <a href="https://www.alibaba.com/showroom/kumar-shirts.html" target="_blank">
#         kumar shirts
#        </a>
# <a href="https://www.alibaba.com/showroom/batik-shirt.html" target="_blank">
#         batik shirt
#        </a>
# <a href="https://www.alibaba.com/showroom/jeans-shirt.html" target="_blank">
#         jeans shirt
#        </a>
# <a href="https://www.alibaba.com/showroom/men-shirts.html" target="_blank">
#         men shirts
#        </a>
# <a href="https://www.alibaba.com/showroom/tuxedo-shirt.html" target="_blank">
#         tuxedo shirt
#        </a>
# <a href="https://www.alibaba.com/showroom/black-shirt.html" target="_blank">
#         black shirt
#        </a>
# <a href="https://www.alibaba.com/showroom/floral-shirt.html" target="_blank">
#         floral shirt
#        </a>
# <a href="https://www.alibaba.com/showroom/pilot-shirt.html" target="_blank">
#         pilot shirt
#        </a>
# <a href="https://www.alibaba.com/showroom/plaid-shirt.html" target="_blank">
#         plaid shirt
#        </a>
# <a href="https://www.alibaba.com/showroom/silk-shirt.html" target="_blank">
#         silk shirt
#        </a>
# <a href="https://www.alibaba.com/showroom/khadi-shirts.html" target="_blank">
#         khadi shirts
#        </a>
# <a href="https://www.alibaba.com/showroom/eton-shirts.html" target="_blank">
#         eton shirts
#        </a>
# <a href="https://www.alibaba.com/showroom/check-shirt.html" target="_blank">
#         check shirt
#        </a>
# </div>
# </div>
# </div>
# <div class="module_report" data-module-name="module_report">
# <div class="report-layout">
# <svg class="detail-symbol">
# <use xlink:href="#icon-flag">
# </use>
# </svg>
# <a class="report-link" href="//my-health.alibaba.com/helpCenter/mainTab.htm" target="_blank">
#        Report abuse
#       </a>
# </div>
# </div>
# </div>
# <div class="" data-section="SectionCommonFooter">
# </div>
# <div class="" data-section="SectionCommonSideBar">
# <div class="detail-sidebar-layout">
# <div class="detail-sidebar-tooltip-wrapper">
# <div class="detail-sidebar-contact-supplier">
# <div class="im-alitalk-container" style="cursor:pointer">
# <svg class="detail-sidebar-icon" height="20" width="20">
# <use xlink:href="#icon-email">
# </use>
# </svg>
# </div>
# </div>
# <span class="detail-sidebar-tooltip-text">
#        Contact supplier
#       </span>
# </div>
# <div class="detail-sidebar-tooltip-wrapper">
# <div class="detail-sidebar-chat-now">
# <div class="im-alitalk-container" style="cursor:pointer">
# <img class="detail-sidebar-portrait" src="//atmgateway-client.alibaba.com/atmgateway/get_portrait.htm?memberId=8pctgRBMALP9ftNBH%2FSAW1II4s%2FyiBaR6wdkfYSa%2Bs4%3D"/>
# </div>
# </div>
# <span class="detail-sidebar-tooltip-text">
#        Chat now
#       </span>
# </div>
# <div class="detail-sidebar-tooltip-wrapper">
# <a class="detail-sidebar-survey" href="https://survey.alibaba.com/apps/zhiliao/FhrIRFb6J?cna=undefined&amp;mbr_id=" target="_blank">
# <svg class="detail-sidebar-icon" height="20" width="20">
# <use xlink:href="#icon-survey">
# </use>
# </svg>
# </a>
# <span class="detail-sidebar-tooltip-text">
#        Survey
#       </span>
# </div>
# <div class="detail-sidebar-back-to-top">
# <svg class="detail-sidebar-icon" height="20" stroke-width="4" width="20">
# <use xlink:href="#icon-go-top">
# </use>
# </svg>
# </div>
# </div>
# </div>
# </div>
# <div id="layout-other">
# </div>
# <script>
#    // 同构渲染结束打点
#         window.__BB_time4=Date.now();
#         // TODO: 待逻辑迁移到 __global_config__ 后删除
#         window.__version__map = {
#             'magicEditLoaderVersion': '0.0.75',
#             'icbuPcDetailAll': '0.0.9'
#         }
#                 window.__global_config__ = {
#             perfConfig: {
#                 bbScript: '//s.alicdn.com/@g/big-brother/sentry/3.x/index.js'
#             },
#             version__map: {
#                 'magicEditLoaderVersion': '0.0.75',
#                 'icbuPcDetailAll': '0.0.9'
#             },
#             //   管理异步资源
#             deferAssets:{
#                 gdpr: {
#                     js: "//s.alicdn.com/@g/msite/gdpr-cookie-notice/1.0.5/index.js",
#                     cbFn: function () {}
#                 },
#                 semRemarket: {
#                     js: "//s.alicdn.com/@g/sc/cdn-sem-remarketing/0.0.6/main.js"
#                 }
#             }
#         };
#         window.detailData = {"devData":{"hierarchyConfig":{"detail_service_section_order_pc_test":{"hierarchyData":{"layout-left":["module_title","module_comment","module_company","module_productImage","module_recommend","module_service","module_attribute","module_review","module_sample","module_detail_selection_tool","module_certification","module_lead","module_customization","module_project","module_card","module_unifed_company_card","module_description"]},"value":"test"}},"i18nConfig":{"navigation.contact_contact":[{"globalDataKeys":"abtest.pc_detail_send_inquiry","assignment":"supplierCard.action.orderBtn","value":"test"}]}},"globalData":{"abtest":{"detail_review_floor":"VO","reviewNewTest":"VO","ShopReviewTest":"VO","certificateTest":"certificate_high","ds_in_detail_pc":"VO","product_reviews":"VO","deliveryGuaranteeTest":"VA","FixPriceAppTest":"VO","pc_old_detail_main_action":"VO","productReviewTest":"VO","ds_in_detail_app":"VO","pc_detail_multi_lang_text":"VO","PoOfflineTest":"noButton","pc_detail_company_card_20241212":"VO","GlobalTopProductTest":"VO","pc_action_optimisation_2":"VO","chatStrongTest":"VO","csTestVersion":"VA","RTSByCountryTest":"VO","goldCompanyCardTest":"VA","MinisiteEntranceTest":"VO","pc_detail_send_order_request":"VO","wap_detail_ui_upgrade":"VO","RecommendListTest":"entrance_with_url_recommend_after_sample","FixPricePcTest":"VO","MainPictureTest":"VO"},"buyer":{"coreCountry":true,"fastFeedBackView":{"crossdomainToken":"V10ld5IY+78S/P7rl9J45KmAMZ7SIwwinSrwnSOHCD9t4HyfGfP126zwbbNjCm5uXb","feedBackDomain":"1","feedBackObjectEncryptId":"IDX1EkFfBJJKPGU4UYAYm1SrBfgDBJTWet39aNKylq8EccIk41HLP4TSt2xUa49C6m4w","feedBackObjectId":"1601352569953","inquiryFor":"company","pageName":"productDetail","umidToken":"B8556c0776eec964f2fcd015fbe22b856"},"shippingToCountry":"US"},"extend":{"showSA":false,"questionnaire":"{\"ICBU_DETAIL_QUESTIONNAIRE_PC\":[{\"materialJSON\":[{\"nameDesc\":\"问卷地址\",\"size\":{},\"name\":\"url\",\"type\":\"link\",\"isNecessary\":\"true\",\"value\":\"https://survey.alibaba.com/apps/zhiliao/NXhC3EiUz\"},{\"nameDesc\":\"背景图片\",\"size\":{},\"name\":\"background\",\"type\":\"img\",\"isNecessary\":\"true\",\"value\":\"https://img.alicdn.com/imgextra/i2/O1CN01uNjRut1CqUxAHU9yu_!!6000000000132-2-tps-960-102.png\"},{\"nameDesc\":\"标题\",\"size\":{},\"name\":\"title\",\"type\":\"text\",\"isNecessary\":\"true\",\"value\":\"Your Opinion Matters: Complete Our Survey\"},{\"nameDesc\":\"说明\",\"size\":{},\"name\":\"description\",\"type\":\"text\",\"isNecessary\":\"true\",\"value\":\"Help us enhance our platform: Share your feedback on the product.\"},{\"nameDesc\":\"按钮\",\"size\":{},\"name\":\"button\",\"type\":\"text\",\"isNecessary\":\"true\",\"value\":\"Rate your experiences\"}]}],\"ICBU_DETAIL_QUESTIONNAIRE_MOBILE\":[{\"materialJSON\":[{\"size\":{},\"name\":\"url\",\"type\":\"link\",\"isNecessary\":\"true\",\"value\":\"https://survey.alibaba.com/apps/zhiliao/XDBZjcSJ6\"}]}]}","protectionType":["easyReturn","taAssurance","safePayment"],"atmosphereConfig":"","promotionIcon":"https://s.alicdn.com/@img/imgextra/i3/O1CN01vyjd0W1FSB7PNiQyK_!!6000000000485-2-tps-80-32.png","previewDetail":{},"detailId":1601352569953,"banner":{"items":[{"nicheMaterialList":[],"pageNo":-1,"pageSize":-1,"totalNum":-1}],"resultCode":"200","totalCount":1},"atmospherePopConfig":"","photoUrl":"https://sc04.alicdn.com/kf/Hc15cc3be8cfa4c248712db9b9c098297E.jpg_80x80.jpg","pcSemiSwitch":true,"atmSecurityToken":"dlorcjF3RkQxam5tSWdwYm1ESnRWKzNkRjhIOS9XbjdnZWdBS1BOU1FDZldsQWt0VVdXbVQvSDdQendTSFcrUHNmZ1c3TDNLeDFFUDN1bjRHeUM5SjdxdktGR25kRVluaHFBV29UZUFZVElYRE96Q0xzMGJRUndZSVFmWlFrWk9xNTRMcGNaMVVER2F6VTR3dEJzNTZBPT0mdmVyc2lvbj0xLjAuMA==","promoConfig":"","productOwnMemberAlitalkEncryptId":"8pctgRBMALP9ftNBH/SAW1II4s/yiBaR6wdkfYSa+s4=","detailEncryptId":"IDX1NHL1y_cVM5TQhZzZ2X9ELKWihDjdaOUtjfox5Hs2lPiWIvGHSEDluOuFXU1oNcdo"},"global":{"alisite":[{"appName":"alisite","data":{"title":"Alisite Facade","scene":"companyKeyCapacity"},"modules":[{"nam ...
#                 window.detailData.scVersion = "1.0.68";
#   </script>
# <script>
#    // TODO: 逻辑待收口
#         try {
#             var detailLinks = {};
#             '{indonesian=//indonesian.alibaba.com/product-detail/MereSports-Men-s-100-Merino-Wool-1601352569953.html, german=//german.alibaba.com/product-detail/MereSports-Men-s-100-Merino-Wool-1601352569953.html, spanish=//spanish.alibaba.com/product-detail/MereSports-Men-s-100-Merino-Wool-1601352569953.html, russian=//russian.alibaba.com/product-detail/MereSports-Men-s-100-Merino-Wool-1601352569953.html, hebrew=//hebrew.alibaba.com/product-detail/MereSports-Men-s-100-Merino-Wool-1601352569953.html, italian=//italian.alibaba.com/product-detail/MereSports-Men-s-100-Merino-Wool-1601352569953.html, thai=//thai.alibaba.com/product-detail/MereSports-Men-s-100-Merino-Wool-1601352569953.html, vietnamese=//vietnamese.alibaba.com/product-detail/MereSports-Men-s-100-Merino-Wool-1601352569953.html, korean=//korean.alibaba.com/product-detail/MereSports-Men-s-100-Merino-Wool-1601352569953.html, dutch=//dutch.alibaba.com/product-detail/MereSports-Men-s-100-Merino-Wool-1601352569953.html, chinese=//chinese.alibaba.com/product-detail/MereSports-Men-s-100-Merino-Wool-1601352569953.html, japanese=//japanese.alibaba.com/product-detail/MereSports-Men-s-100-Merino-Wool-1601352569953.html, arabic=//arabic.alibaba.com/product-detail/MereSports-Men-s-100-Merino-Wool-1601352569953.html, turkish=//turkish.alibaba.com/product-detail/MereSports-Men-s-100-Merino-Wool-1601352569953.html, hindi=//hindi.alibaba.com/product-detail/MereSports-Men-s-100-Merino-Wool-1601352569953.html, english=//www.alibaba.com/product-detail/MereSports-Men-s-100-Merino-Wool_1601352569953.html, portuguese=//portuguese.alibaba.com/product-detail/MereSports-Men-s-100-Merino-Wool-1601352569953.html, french=//french.alibaba.com/product-detail/MereSports-Men-s-100-Merino-Wool-1601352569953.html}'.replace(/{|}/g, '').split(',').forEach(function(item) {
#                 var sp = item.trim().split('=')
#                 var ecology_token = window.location.href.split('ecology_token=');
#                 if (ecology_token.length === 2) {
#                     detailLinks[sp[0]] = sp[1] + '?ecology_token=' + ecology_token[1]
#                 }else{
#                     detailLinks[sp[0]] = sp[1]
#                 }
#             });
#             var languageMaps = {
#                 en_US:'english',
#                 de_DE:'german',
#                 pt_PT:'portuguese',
#                 es_ES:'spanish',
#                 fr_FR:'french',
#                 it_IT:'italian',
#                 hi_IN:'hindi',
#                 ru_RU:'russian',
#                 ko_KR:'korean',
#                 ja_JP:'japanese',
#                 ar_SA:'arabic',
#                 th_TH:'thai',
#                 tr_TR:'turkish',
#                 vi_VN:'vietnamese',
#                 nl_NL:'dutch',
#                 iw_IL:'hebrew',
#                 in_ID:'indonesian',
#                 zh_CN: 'chinese'
#             };
#         } catch(e) {
#             var detailLinks = null;
#             var languageMaps = null;
#         }
#         if (detailLinks && languageMaps) {
#             window.__language_fast_mode = 'true';
#             window.HEADER_DATA = window.HEADER_DATA || {};
#             window.HEADER_DATA["sc-header-config"] = window.HEADER_DATA["sc-header-config"] || {};
#             window.HEADER_DATA["sc-header-config"].languageMaps = languageMaps;
#             window.HEADER_DATA["sc-header-config"].detailLinks = detailLinks;
#         }
#   </script>
# <style>
#    #detail_decorate_root .J_module[module-name=icbu-pc-timeLimitDiscount] .bc-time-limit-discount{
#             padding:0!important;
#         }
#
#         #detail_decorate_root .J_module[module-name=icbu-pc-timeLimitDiscount] .next-row{
#             display:flex;
#         }
#
#         #detail_decorate_root .J_module[module-name=icbu-pc-timeLimitDiscount] .icbu-mod-wrapper{
#             background:#ededed;
#         }
#   </style>
# <script defer="" src="//s.alicdn.com/@g/code/lib/??react/18.2.0/umd/react.production.min.js,react-dom/18.2.0/umd/react-dom.production.min.js" type="text/javascript">
# </script>
# <script defer="" src="https://s.alicdn.com/@g/ife/libs/1.0.13/??next/dpl-icbu-storebuilder/next.min.js">
# </script>
# <script defer="" src="//s.alicdn.com/@g/icbu-decorate/??icbu-mod-lib/1.0.12/no-next.js">
# </script>
# <script defer="" src="//s.alicdn.com/@g/sc/detail-fantasy/0.1.107/index.js" type="text/javascript">
# </script>
# <script defer="" src="//s.alicdn.com/@g/sc/detail-fantasy/0.1.107/globalHeader.js" type="text/javascript">
# </script>
# <script defer="" src="//s.alicdn.com/@g/code/npm/@ali/icbu-xman-inlet/1.0.4/loadXman.umd.es5.production.js" type="text/javascript">
# </script>
# <script defer="" onload="itraceBundleReady()" src="//s.alicdn.com/@g/woodpeckerx/itrace-next/itrace.iife.js" type="text/javascript">
# </script>
# <script>
#    try {
#             window.__itrace_conf = {
#                 rel: (function(){
#                     if(detailData.globalData?.product?.semiHosted) {
#                         return 'semi_scene'
#                     } else if(detailData.globalData?.trade?.hasLogistics) {
#                         return 'rts_scene'
#                     }
#                     return 'inquiry_scene'
#                 })(),
#                 bid: `2kjww89c-tgozwrq6`,
#                 plugins: [{
#                     id: 'blank',
#                     startCheckingTime: 1000,
#                     rootDom: function(){
#                         return document.getElementById(detailData.renderId || 'container')
#                     },
#                 }]
#             }
#             function itraceBundleReady () {
#                 __itrace.setReady()
#             }
#         } catch (error) {
#             console.warn(error)
#         }
#   </script>
# <script>
#    (function() {
#                 var SEMR = window.SEM_REMARKETING_DATA || {};
#                 SEMR.productId = '1601352569953';
#                                     SEMR.siteName = 'detail';
#                     SEMR.productType='detail';
#                                 SEMR.pageType = 'detail';
#                 window.SEM_REMARKETING_DATA = SEMR;
#             })();
#   </script>
# <!-- tangram:7095 begin-->
# <script type="application/ld+json">
#    [
#             {
#                 "@context": "https://schema.org/",
#                 "@type": "Product",
#                 "@id": "1601352569953",
#         "name": "MereSports Men's 100% Merino Wool T-Shirts Premium Comfort Durability Casual Fit Short Sleeve Fitness Shirts",
#                 "image": ["https://sc04.alicdn.com/kf/H7a1ce823c3b04b5a9031fd56048c7543w.png","https://sc04.alicdn.com/kf/Hd7d78cc092b4418f8abcfc633e9dbbd5u.png","https://sc04.alicdn.com/kf/H4d022a933c1d4429b17d25d97f691ce2q.png","https://sc04.alicdn.com/kf/H916128c9d7cd49a98ae3cdf5d551be2cP.png","https://sc04.alicdn.com/kf/H9833b4a6d4c24630b6bbe886f4973886j.png","https://sc04.alicdn.com/kf/H6610477d780e4a90beddae86fff6c9889.png"],
#                 "description": "Meresports Men&#39;s 100% Merino Wool T-shirts Premium Comfort Durability Casual Fit Short Sleeve Fitness Shirts , Find Complete Details about Meresports Men&#39;s 100% Merino Wool T-shirts Premium Comfort Durability Casual Fit Short Sleeve Fitness Shirts from Shanghai Meresports Apparel Co., Ltd. Supplier or Manufacturer on Alibaba.com",
#         "sku": "1601352569953",
#         "mpn": "1601352569953-00",
#                 "brand": {
#         "@type": "Brand",
#         "name": "Shanghai Meresports Apparel Co., Ltd."
#         }
#                 ,
#         "offers": {
#             "@type": "Offer",
#                         "url":"https://www.alibaba.com/product-detail/MereSports-Men-s-100-Merino-Wool_1601352569953.html",
#                         "offerCount": 1,
#             "availability": "http://schema.org/InStock",
#                     "priceCurrency": "USD",
#             "price": "15.5"
#                             ,
#             "priceValidUntil": "2026-03-03"
#                 }
#                     ,
#             "review":[
#                  {
#                     "@type":"Review",
#                     "author":{
#                             "@type": "Person",
#                             "name":"anonymous"
#                         },
#                     "reviewRating":{
#                         "@type":"Rating",
#                         "ratingValue":"5.0",
#                     "bestRating":"5"
#                  }
#              }
#         ]
#                 }
#                 ,
#         {
#         "@context": "https://schema.org",
#         "@type": "ImageObject",
#         "contentUrl": "https://sc04.alicdn.com/kf/H7a1ce823c3b04b5a9031fd56048c7543w.png",
#         "creditText": "Alibaba",
#                 "creator": {
#             "@type": "Person",
#             "name": "Shanghai Meresports Apparel Co., Ltd."
#         }
#             }
#     ,        {
#         "@context": "https://schema.org",
#         "@type": "ImageObject",
#         "contentUrl": "https://sc04.alicdn.com/kf/Hd7d78cc092b4418f8abcfc633e9dbbd5u.png",
#         "creditText": "Alibaba",
#                 "creator": {
#             "@type": "Person",
#             "name": "Shanghai Meresports Apparel Co., Ltd."
#         }
#             }
#     ,        {
#         "@context": "https://schema.org",
#         "@type": "ImageObject",
#         "contentUrl": "https://sc04.alicdn.com/kf/H4d022a933c1d4429b17d25d97f691ce2q.png",
#         "creditText": "Alibaba",
#                 "creator": {
#             "@type": "Person",
#             "name": "Shanghai Meresports Apparel Co., Ltd."
#         }
#             }
#     ,        {
#         "@context": "https://schema.org",
#         "@type": "ImageObject",
#         "contentUrl": "https://sc04.alicdn.com/kf/H916128c9d7cd49a98ae3cdf5d551be2cP.png",
#         "creditText": "Alibaba",
#                 "creator": {
#             "@type": "Person",
#             "name": "Shanghai Meresports Apparel Co., Ltd."
#         }
#             }
#     ,        {
#         "@context": "https://schema.org",
#         "@type": "ImageObject",
#         "contentUrl": "https://sc04.alicdn.com/kf/H9833b4a6d4c24630b6bbe886f4973886j.png",
#         "creditText": "Alibaba",
#                 "creator": {
#             "@type": "Person",
#             "name": "Shanghai Meresports Apparel Co., Ltd."
#         }
#             }
#     ,        {
#         "@context": "https://schema.org",
#         "@type": "ImageObject",
#         "contentUrl": "https://sc04.alicdn.com/kf/H6610477d780e4a90beddae86fff6c9889.png",
#         "creditText": "Alibaba",
#                 "creator": {
#             "@type": "Person",
#             "name": "Shanghai Meresports Apparel Co., Ltd."
#         }
#             }
#             ]
#   </script>
# <script type="application/ld+json">
#    {
#               "@context": "https://schema.org",
#               "@type": "BreadcrumbList",
#               "itemListElement": [
#                                 {
#                   "@type": "ListItem",
#                   "position": 1,
#                   "name": "Home",
#                   "item": "https://www.alibaba.com"
#                 },                                {
#                   "@type": "ListItem",
#                   "position": 2,
#                   "name": "Apparel & Accessories",
#                   "item": "https://www.alibaba.com/Apparel-Accessories_p3"
#                 },                                {
#                   "@type": "ListItem",
#                   "position": 3,
#                   "name": "Men's Clothing",
#                   "item": "https://www.alibaba.com/Men-s-Clothing_pid127726318"
#                 },                                {
#                   "@type": "ListItem",
#                   "position": 4,
#                   "name": "Men's T-Shirts",
#                   "item": "https://www.alibaba.com/Men-s-T-Shirts_pid127734143"
#                 }                                ]
#             }
#   </script>
# <!-- tangram:7095 end-->
# </body>
# </html>

# %% [markdown]
# *Here, we make an HTTP GET request to the URL and parse the page's HTML content using BeautifulSoup. We also prettify the HTML for better readability and print it out for inspection.*
#
# ---
#
# ### **4. Extracting the Product Title**

# %%
# Find the product title using its HTML tag and attribute
title = soup2.find('h1')['title']
print(title)
# Out:
# MereSports Men's 100% Merino Wool T-Shirts Premium Comfort Durability Casual Fit Short Sleeve Fitness Shirts

# %% [markdown]
# *This section extracts the product title by finding the `<h1>` tag and accessing the `title` attribute.*

# %% [markdown]
# ---
# ### **5. Scraping Price and Quantity Information**

# %%
# Find all price items on the page
price_items = soup2.find_all('div', class_='price-item')

# Initialize an empty list to store price and quantity data
price_info = []

# Loop through each price item to extract quantity and price
for item in price_items:
    quantity = item.find('div', class_='quality').text.strip().replace('pieces', '')
    price = item.find('span').text.strip()
    price_info.append([quantity, price])

# Output the extracted data (optional)
print(price_info)
# Out:
# [['500 - 1999 ', '$16.50'], ['>= 2000 ', '$15.50']]

# %% [markdown]
# *This part finds all the price-related items on the page and extracts the quantity and price for each. The quantity is cleaned to remove the "pieces" text.*
#
# ---
#
# ### **6. Timestamp for Data Collection**

# %%
# Create a timestamp for the data collection date
today = datetime.date.today()
print(today)
# Out:
# 2025-03-03

# %% [markdown]
# *This section generates the current date, which will be used to track when the data was collected.*
#
# ---
#
# ### **7. Organize Data for Output**

# %%
# Organize the scraped data into a structured format
data = []
for i in range(len(price_info)):
    quantity = price_info[i][0]
    price = price_info[i][1]
    data.append([title, quantity, price, today])

# Output the organized data (optional)
print(data)
# Out:
# [["MereSports Men's 100% Merino Wool T-Shirts Premium Comfort Durability Casual Fit Short Sleeve Fitness Shirts", '500 - 1999 ', '$16.50', datetime.date(2025, 3, 3)], ["MereSports Men's 100% Merino Wool T-Shirts Premium Comfort Durability Casual Fit Short Sleeve Fitness Shirts", '>= 2000 ', '$15.50', datetime.date(2025, 3, 3)]]

# %% [markdown]
# *We organize the scraped price and quantity information, along with the product title and collection date, into a structured list.*
#
# ---
#
# ### **8. Saving Data to CSV**

# %%
# Define column headers for the DataFrame
header = ['Title', 'Quantity', 'Price', 'Date']

# Create a DataFrame using the scraped data
df = pd.DataFrame(data, columns=header)

# Display the DataFrame (optional)
df

# Save the DataFrame to a CSV file
df.to_csv(r"C:\Users\user\Desktop\studying\1- python\python projects\web scraping\alibaba_data_scraped.csv", index=False)

# %% [markdown]
# *Finally, we create a pandas DataFrame to organize the data in a table format. Then, we save the DataFrame to a CSV file for further analysis.*
